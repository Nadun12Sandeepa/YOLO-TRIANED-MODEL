# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="vKSFVoXw5W1BLN5NMbwq")
project = rf.workspace("aegis").project("pothole-detection-i00zy")
version = project.version(10)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Pothole-Detection--10 in yolov11:: 100%|██████████| 6992/6992 [00:00<00:00, 7861.59it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 17.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# load a COCO-pretrained YOLO11 small model
model = YOLO("yolo11n.pt")

# train on your dataset
results = model.train(data="/content/Pothole-Detection--10/data.yaml", epochs=50, imgsz=640, batch=16, device=0)

# evaluate
metrics = model.val()
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.223 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load your trained or pretrained YOLO11 model
model = YOLO("/content/runs/detect/train/weights/best.pt")   # or "yolo11n.pt" if you're using pretrained

# Run prediction on a video file
results = model.predict(
    source="/content/video 1.mp4",    # path to your video file
    imgsz=640,             # image size for inference
    conf=0.25,             # confidence threshold (default 0.25)
    save=True,             # save output video
    show=True              # show video window while predicting
)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/821) /content/video 1.mp4: 640x384 2 potholes, 52.6ms
# video 1/1 (frame 2/821) /content/video 1.mp4: 640x384 2 potholes, 8.8ms
# video 1/1 (frame 3/821) /content/video 1.mp4: 640x384 3 potholes, 15.8ms
# video 1/1 (frame 4/821) /content/video 1.mp4: 640x384 4 potholes, 9.2ms
# video 1/1 (frame 5/821) /content/video 1.mp4: 640x384 3 potholes, 8.4ms
# ...
